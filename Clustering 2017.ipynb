# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

dataPipe = pd.read_excel('Nilai Master Pipe.xlsx')
data = dataPipe.drop(['nama'],axis=1)
data = data.rename(columns={'nim': 'NIM'})
data.head()
# Out:
#           NIM  OOP  RPB   PI  APSI  WEB  Statistik  Matdis  Alpro  Strukdat  \
# 0  1202170006  4.0  3.5  2.0   2.0  3.5        4.0     2.5    3.5       2.5
# 1  1202170010  4.0  3.5  4.0   2.5  4.0        3.0     4.0    3.0       4.0
# 2  1202170011  4.0  3.0  3.5   2.0  3.5        3.5     3.5    3.5       4.0
# 3  1202170015  4.0  3.5  3.5   3.5  3.5        3.5     3.5    4.0       4.0
# 4  1202170018  2.0  2.5  3.0   3.5  3.5        2.5     2.5    3.0       3.5
#
#     SE   PO  SCM   EA  Basdat  Manjarkom  Sisop  MSDM  Desjar  Manprosi
# 0  4.0  3.0  3.0  3.0     3.0        3.0    3.0   3.5     3.5       2.5
# 1  4.0  3.5  3.0  3.5     3.5        3.5    3.0   3.5     3.5       3.0
# 2  4.0  3.5  3.5  3.5     4.0        3.5    3.0   4.0     3.5       3.0
# 3  3.5  2.5  3.5  3.0     3.5        3.0    3.5   3.5     3.5       2.5
# 4  3.5  3.5  2.5  3.5     3.0        2.5    3.0   3.5     2.0       3.5

# %%
dataTambahan = pd.read_excel('Nilai Tambahan 2016 - Pipe.xlsx')
dataTambahan = dataTambahan.drop(['nama'],axis=1)
dataTambahan = dataTambahan.rename(columns={'nim': 'NIM'})
data = data.append(dataTambahan)
data.head()
# Out:
#           NIM  OOP  RPB   PI  APSI  WEB  Statistik  Matdis  Alpro  Strukdat  \
# 0  1202170006  4.0  3.5  2.0   2.0  3.5        4.0     2.5    3.5       2.5
# 1  1202170010  4.0  3.5  4.0   2.5  4.0        3.0     4.0    3.0       4.0
# 2  1202170011  4.0  3.0  3.5   2.0  3.5        3.5     3.5    3.5       4.0
# 3  1202170015  4.0  3.5  3.5   3.5  3.5        3.5     3.5    4.0       4.0
# 4  1202170018  2.0  2.5  3.0   3.5  3.5        2.5     2.5    3.0       3.5
#
#     SE   PO  SCM   EA  Basdat  Manjarkom  Sisop  MSDM  Desjar  Manprosi
# 0  4.0  3.0  3.0  3.0     3.0        3.0    3.0   3.5     3.5       2.5
# 1  4.0  3.5  3.0  3.5     3.5        3.5    3.0   3.5     3.5       3.0
# 2  4.0  3.5  3.5  3.5     4.0        3.5    3.0   4.0     3.5       3.0
# 3  3.5  2.5  3.5  3.0     3.5        3.0    3.5   3.5     3.5       2.5
# 4  3.5  3.5  2.5  3.5     3.0        2.5    3.0   3.5     2.0       3.5

# %%
from ipynb.fs.full.Cluster_v1 import clustering_peminatan as getLabel

techno = getLabel(data,'OOP','RPB','WEB','PI')
techno.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
ead = getLabel(data,'OOP','APSI','RPB','WEB')
ead.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
edm = getLabel(data,'Statistik', 'Matdis', 'Alpro', 'Strukdat')
edm.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
erp = getLabel(data,'SE','RPB','PO','SCM')
erp.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
ea = getLabel(data,'RPB','APSI','EA','Basdat')
ea.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
eim = getLabel(data,'Desjar','Manjarkom','Sisop','Manprosi')
eim.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
ism = getLabel(data,'SE','Manjarkom','Sisop','MSDM')
ism.head()
# Out:
#           NIM  Label
# 0  1202170006      1
# 1  1202170010      1
# 2  1202170011      1
# 3  1202170015      1
# 4  1202170018      1

# %%
techno.to_csv('peminatan2017_csv/techno.csv')
ead.to_csv('peminatan2017_csv/ead.csv')
edm.to_csv('peminatan2017_csv/edm.csv')
erp.to_csv('peminatan2017_csv/erp.csv')
ea.to_csv('peminatan2017_csv/ea.csv')
eim.to_csv('peminatan2017_csv/eim.csv')
ism.to_csv('peminatan2017_csv/ism.csv')

# %%
from ipynb.fs.full.Cluster_v1 import filter_csv

techno = filter_csv("peminatan2017_csv/techno.csv")
ea = filter_csv("peminatan2017_csv/ea.csv")
ead = filter_csv("peminatan2017_csv/ead.csv")
edm = filter_csv("peminatan2017_csv/edm.csv")
erp = filter_csv("peminatan2017_csv/erp.csv")
ism = filter_csv("peminatan2017_csv/ism.csv")
eim = filter_csv("peminatan2017_csv/eim.csv")

# %%
matriks = pd.DataFrame(data.NIM)
matriks['Technopreneur'] = techno.Label
matriks['EAD'] = ead.Label
matriks['ERP'] = erp.Label
matriks['EDM'] = edm.Label
matriks['EA'] = ea.Label
matriks['ISM'] = ism.Label
matriks['EIM'] = eim.Label
matriks
# Out:
#             NIM  Technopreneur  EAD  ERP  EDM  EA  ISM  EIM
# 0    1202170006              1    1    1    1   1    1    1
# 1    1202170010              1    1    1    1   1    1    1
# 2    1202170011              1    1    1    1   1    1    1
# 3    1202170015              1    1    1    1   1    1    1
# 4    1202170018              1    1    1    1   1    1    1
# 5    1202170022              1    1    1    1   1    1    1
# 6    1202170023              1    1    1    0   1    1    1
# 7    1202170025              1    1    1    1   1    1    1
# 8    1202170026              1    1    1    1   1    1    1
# 9    1202170029              1    1    1    0   1    1    1
# 10   1202170030              0    0    1    0   0    1    1
# 11   1202170035              1    1    1    1   0    1    0
# 12   1202170038              1    1    1    1   1    1    1
# 13   1202170042              1    1    1    1   1    1    1
# 14   1202170043              0    0    1    0   1    1    0
# ...

# %%
hasilPeminatan = pd.read_excel('hasilpeminatanpipe.xlsx')
hasilPeminatan = hasilPeminatan.drop(['No','Nama','Mata Kuliah','Kode Mata Kuliah','Kelas Mata Kuliah','ID'],axis=1)
hasilPeminatan.head()
# Out:
#           NIM                      Peminatan
# 0  1202170258   Enterprise Resource Planning
# 1  1202174065     Enterprise Data Management
# 2  1202174208  Enterprise System Development
# 3  1202174372     Enterprise Data Management
# 4  1202170180  Enterprise System Development

# %%
hasilPeminatan = hasilPeminatan.sort_values(by ='NIM')
hasilPeminatan = hasilPeminatan.iloc[11::]
hasilPeminatan
# Out:
#             NIM                             Peminatan
# 268  1202170006         Information System Management
# 24   1202170010         Enterprise System Development
# 65   1202170011         Information System Management
# 153  1202170015            Enterprise Data Management
# 164  1202170018               Enterprise Architecture
# 211  1202170022            Enterprise Data Management
# 31   1202170023         Enterprise System Development
# 187  1202170025         Information System Management
# 55   1202170026         Enterprise System Development
# 64   1202170029         Enterprise System Development
# 168  1202170030                         Technopreneur
# 314  1202170035                         Technopreneur
# 77   1202170038         Enterprise System Development
# 192  1202170042         Enterprise System Development
# 354  1202170043  Enterprise Infrastructure Management
# 287  1202170044  Enterprise Infrastructure Management
# ...

# %%
temp = [0] * len(matriks)
for indeks, baris in matriks.iterrows() :
    for index, row in hasilPeminatan.sort_values(by ='NIM').iterrows() :
        if baris['NIM'] == row['NIM'] :
            if row['Peminatan'] == "Information System Management" :
                temp[indeks] = "ISM"
            elif row['Peminatan'] == "Enterprise System Development" :
                temp[indeks] = "EAD"
            elif row['Peminatan'] == "Enterprise Data Management" :
                temp[indeks] = "EDM"
            elif row['Peminatan'] == "Enterprise Architecture" :
                temp[indeks] = "EA"
            elif row['Peminatan'] == "Technopreneur" :
                temp[indeks] = "TECHNO"
            elif row['Peminatan'] == "Enterprise Infrastructure Management" :
                temp[indeks] = "EIM"
            elif row['Peminatan'] == "Enterprise Resource Planning" :
                temp[indeks] = "ERP"
            break
        else :
            temp[indeks] = "Tidak Memilih"

# %%
matriks["Peminatan"] = temp
matriks.head()
# Out:
#           NIM  Technopreneur  EAD  ERP  EDM  EA  ISM  EIM Peminatan  \
# 0  1202170006              1    1    1    1   1    1    1       ISM
# 1  1202170010              1    1    1    1   1    1    1       EAD
# 2  1202170011              1    1    1    1   1    1    1       ISM
# 3  1202170015              1    1    1    1   1    1    1       EDM
# 4  1202170018              1    1    1    1   1    1    1        EA
#
#       Keterangan
# 0          Cocok
# 1  Tidak Memilih
# 2          Cocok
# 3          Cocok
# 4          Cocok

# %%
isCocok = [0] * len(matriks)
for index, row in matriks.iterrows():
    if row['Peminatan'] == 'TECHNO':
        if row['Technopreneur'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'EAD':
        if row['EAD'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'EDM':
        if row['EDM'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'ERP':
        if row['ERP'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'EAA' or row['Peminatan'] == 'EA':
        if row['EA'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'ISM':
        if row['ISM'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    elif row['Peminatan'] == 'EIM':
        if row['EIM'] == 1 :
            isCocok[index] = "Cocok"
        else :
            isCocok[index] = "Tidak Cocok"
    else :
        isCocok[index] = "Tidak Memilih"

# %%
matriks["Keterangan"] = isCocok
matriks.head()
# Out:
#           NIM  Technopreneur  EAD  ERP  EDM  EA  ISM  EIM Peminatan Keterangan
# 0  1202170006              1    1    1    1   1    1    1       ISM      Cocok
# 1  1202170010              1    1    1    1   1    1    1       EAD      Cocok
# 2  1202170011              1    1    1    1   1    1    1       ISM      Cocok
# 3  1202170015              1    1    1    1   1    1    1       EDM      Cocok
# 4  1202170018              1    1    1    1   1    1    1        EA      Cocok

# %%
jumlah_cocok = 0
jumlah_tidak_cocok = 0
jumlah_tidak_memilih = 0

for index, row in matriks.iterrows():
    if row['Keterangan'] == "Cocok" :
        jumlah_cocok = jumlah_cocok + 1
    elif row['Keterangan'] == "Tidak Cocok" :
        jumlah_tidak_cocok = jumlah_tidak_cocok + 1
    else :
        jumlah_tidak_memilih = jumlah_tidak_memilih + 1   
        
data_cocok = [['Cocok', jumlah_cocok],
              ['Tidak Cocok', jumlah_tidak_cocok],
              ['Tidak Memilih', jumlah_tidak_memilih],
              ['Total Mahasiswa', len(matriks)]] 

total_cocok = pd.DataFrame(data_cocok, columns = ['Status', 'Jumlah']) 
  
total_cocok
# Out:
#             Status  Jumlah
# 0            Cocok     309
# 1      Tidak Cocok      47
# 2    Tidak Memilih      18
# 3  Total Mahasiswa     374

# %%
labels = 'Cocok', 'Tidak Cocok', 'Tidak Memilih'
sizes = [jumlah_cocok, jumlah_tidak_cocok, jumlah_tidak_memilih]
colors = ['green', 'red', 'gold']
explode = (0.1, 0, 0)

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
