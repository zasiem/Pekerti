# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

dataPipe = pd.read_excel('Nilai Master Pipe.xlsx')
dataPipe.head()
# Out:
#           nim                                 nama  OOP  RPB   PI  APSI  WEB  \
# 0  1202170006             SHINTA EKA RISA SINURAYA  4.0  3.5  2.0   2.0  3.5
# 1  1202170010  COKORDA AGUNG JAYA LAKSMANA PRAKASA  4.0  3.5  4.0   2.5  4.0
# 2  1202170011                RAFIF FAKHRI RAMADHAN  4.0  3.0  3.5   2.0  3.5
# 3  1202170015                   M IKHSAN PRATAMA P  4.0  3.5  3.5   3.5  3.5
# 4  1202170018                    DINDA SONIA TIARA  2.0  2.5  3.0   3.5  3.5
#
#    Statistik  Matdis  Alpro  ...   SE   PO  SCM   EA  Basdat  Manjarkom  \
# 0        4.0     2.5    3.5  ...  4.0  3.0  3.0  3.0     3.0        3.0
# 1        3.0     4.0    3.0  ...  4.0  3.5  3.0  3.5     3.5        3.5
# 2        3.5     3.5    3.5  ...  4.0  3.5  3.5  3.5     4.0        3.5
# 3        3.5     3.5    4.0  ...  3.5  2.5  3.5  3.0     3.5        3.0
# 4        2.5     2.5    3.0  ...  3.5  3.5  2.5  3.5     3.0        2.5
#
#    Sisop  MSDM  Desjar  Manprosi
# 0    3.0   3.5     3.5       2.5
# ...

# %%
for index, rows in dataPipe.iterrows():
    dataPipe['No'] = index
    
dataPipe.head()
# Out:
#           nim                                 nama  OOP  RPB   PI  APSI  WEB  \
# 0  1202170006             SHINTA EKA RISA SINURAYA  4.0  3.5  2.0   2.0  3.5
# 1  1202170010  COKORDA AGUNG JAYA LAKSMANA PRAKASA  4.0  3.5  4.0   2.5  4.0
# 2  1202170011                RAFIF FAKHRI RAMADHAN  4.0  3.0  3.5   2.0  3.5
# 3  1202170015                   M IKHSAN PRATAMA P  4.0  3.5  3.5   3.5  3.5
# 4  1202170018                    DINDA SONIA TIARA  2.0  2.5  3.0   3.5  3.5
#
#    Statistik  Matdis  Alpro  ...   PO  SCM   EA  Basdat  Manjarkom  Sisop  \
# 0        4.0     2.5    3.5  ...  3.0  3.0  3.0     3.0        3.0    3.0
# 1        3.0     4.0    3.0  ...  3.5  3.0  3.5     3.5        3.5    3.0
# 2        3.5     3.5    3.5  ...  3.5  3.5  3.5     4.0        3.5    3.0
# 3        3.5     3.5    4.0  ...  2.5  3.5  3.0     3.5        3.0    3.5
# 4        2.5     2.5    3.0  ...  3.5  2.5  3.5     3.0        2.5    3.0
#
#    MSDM  Desjar  Manprosi   No
# ...

# %%
import 'Cluster v1.ipynb' as cluster
cluster
# Out:
#   File "<ipython-input-18-3ce6be581ecb>", line 1
#     import 'Cluster v1.ipynb' as cluster
#                             ^
# SyntaxError: invalid syntax
